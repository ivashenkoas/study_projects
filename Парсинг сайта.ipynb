# %% [markdown]
# !pip install bs4 requests

# %%
import re
import time

from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=2&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes=

# %%
# Создаем список URL
URL = r"https://zakupki.gov.ru/epz/order/extendedsearch/results.html?"

# TODO: Изменить номера страниц
FIRST_PAGE = 2
LAST_PAGE = 4

urls_list = [] # создаем пустой список
for page in range(FIRST_PAGE, LAST_PAGE + 1): # перебираем страницы 
    
    # TODO: Варьировать другие параметры, использовать все параметры
    page_url = f'{URL}searchString=&morphology=on&search-filter=Дате+обновления&pageNumber={page}&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes='
    urls_list.append(page_url) # записываем адреса в список
    
print('Длина полученного списка веб-страниц: {}'.format(len(urls_list)))
print('Пример записанных в список страниц: {}'.format(urls_list))
# Out:
# Длина полученного списка веб-страниц: 3
# Пример записанных в список страниц: ['https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=2&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes=', 'https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=3&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes=', 'https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=4&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes=']

# %%
type(urls_list[0])
# Out:
# str

# %%
page = requests.get(urls_list[0]) # попробуем спарсить одну страницу
print(page.status_code) # если 200, то успешно подключились к странице
# Out:
# 200

# %%
urls_list[0]
# Out:
# 'https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=2&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes='

# %%
requests.get(urls_list[1])
# Out:
# <Response [200]>

# %%
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n    \r\n        \r\n        \r\n        \r\n        \r\n        \r\n        \r\n        \r\n        \r\n        \r\n    \r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html>\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<head>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge"/>\r\n    <meta http-equiv="content-type" content="text/html; charset=UTF-8"/>\r\n    <meta name="description" content="Официальный сайт единой информационной системы в сфере закупок 44 ФЗ и 223 ФЗ"/>\r\n    <meta name="apple-itunes-app" content="app-id=1457694118">\r\n    <meta name="google-play-app" content="app-id=ru.gov.zakupki.mobile">\r\n\r\n    <title>Закупки</title>\r\n    <script type="text/javascript">\r\n        var contextPath = "/epz/order/extendedsearch";\r\n        var epzMainPublicUrl = "/epz/main/public/";\r\n        var serverHost = \'/\';\r\n    </script>\r\n\r\n    <script type="text/javascript" src="/static/useractivityrecordplugin/js/recordSupportSystem.js"></script>\r\n\r\n    <link href="/epz/static/images/icons/Portal.ico" rel="shortcut icon">\r\n\r\n    \r\n        \r\n        \r\n            <link type="text/css" rel="stylesheet" media="all" href="/epz/static/css/app.css"/>\r\n        \r\n    \r\n\r\n    <link type="text/css" rel="stylesheet" media="all" href="/epz/static/css/skin.css"/>\r\n    <link type="text/css" rel="stylesheet" href="/epz/static/css/jquery.datepick.css"/>\r\n\r\n    <link type="text/css" rel="stylesheet" href="/epz/static/css/ui.dynatree.css"/>\r\n    \r\n        \r\n        \r\n            <link type="text/css" rel="stylesheet" href="/epz/static/css/jquery_msgbox.css"/>\r\n        \r\n    \r\n    \r\n    \r\n    <script src="/epz/static/js/d3.v5.min.js"></script>\r\n    <script src="/epz/static/js/jquery-3.3.1.min.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/ui_autocomplete.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/jquery-migrate-3.0.1.min.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/validation/jquery.validate.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/mustache.min.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/jquery.price_format.1.7.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/jquery.jcarousel.min.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/jquery.maskedinput.min.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/jquery.cookie.min.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/js.cookie.js"></script>\r\n    <script type="text/javascript">\r\n        $(document).ready(function(){\r\n            var notUsual = (($.cookie("usePoorVisionOption") == \'true\') && $(".goodVisionLink").length == 0);\r\n            var notPoorVision = (($.cookie("usePoorVisionOption") != \'true\') && $(".poorVisionLink").length == 0);\r\n            if (notUsual || notPoorVision){\r\n                location.reload();\r\n            }\r\n        });\r\n        \r\n        $(window).ready(function() {\r\n            $(\'body\').animate({opacity:\'1\'},300);\r\n        });\r\n    </script>\r\n    <script type="text/javascript" src="/epz/static/js/jquery.dynatree.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/jquery.ui.datepicker-ru.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/moment.min.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/moment-timezone.min.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/validation/jquery.numeric.js"></script>\r\n    \r\n    <script type="text/javascript" src="/epz/static/js/action-switch.js"></script>\r\n    <script type="text/javascript" src="/epz/static/js/browser.js"></script>\r\n    \r\n        \r\n        \r\n            <script type="text/javascript" src="/epz/static/js/app.js"></script>\r\n        \r\n   ...

# %%
type(page.text)
# Out:
# str

# %%
soup = BeautifulSoup(page.text, "html.parser") # посмотрим как выглядит спарсенная страница
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Официальный сайт единой информационной системы в сфере закупок 44 ФЗ и 223 ФЗ" name="description"/>
# <meta content="app-id=1457694118" name="apple-itunes-app"/>
# <meta content="app-id=ru.gov.zakupki.mobile" name="google-play-app"/>
# <title>Закупки</title>
# <script type="text/javascript">
#         var contextPath = "/epz/order/extendedsearch";
#         var epzMainPublicUrl = "/epz/main/public/";
#         var serverHost = '/';
#     </script>
# <script src="/static/useractivityrecordplugin/js/recordSupportSystem.js" type="text/javascript"></script>
# <link href="/epz/static/images/icons/Portal.ico" rel="shortcut icon"/>
# <link href="/epz/static/css/app.css" media="all" rel="stylesheet" type="text/css">
# <link href="/epz/static/css/skin.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/epz/static/css/jquery.datepick.css" rel="stylesheet" type="text/css"/>
# <link href="/epz/static/css/ui.dynatree.css" rel="stylesheet" type="text/css"/>
# <link href="/epz/static/css/jquery_msgbox.css" rel="stylesheet" type="text/css"/>
# <script src="/epz/static/js/d3.v5.min.js"></script>
# <script src="/epz/static/js/jquery-3.3.1.min.js"></script>
# <script src="/epz/static/js/ui_autocomplete.js" type="text/javascript"></script>
# <script src="/epz/static/js/jquery-migrate-3.0.1.min.js" type="text/javascript"></script>
# <script src="/epz/static/js/validation/jquery.validate.js" type="text/javascript"></script>
# <script src="/epz/static/js/mustache.min.js" type="text/javascript"></script>
# <script src="/epz/static/js/jquery.price_format.1.7.js" type="text/javascript"></script>
# <script src="/epz/static/js/jquery.jcarousel.min.js" type="text/javascript"></script>
# <script src="/epz/static/js/jquery.maskedinput.min.js" type="text/javascript"></script>
# <script src="/epz/static/js/jquery.cookie.min.js" type="text/javascript"></script>
# <script src="/epz/static/js/js.cookie.js" type="text/javascript"></script>
# <script type="text/javascript">
#         $(document).ready(function(){
#             var notUsual = (($.cookie("usePoorVisionOption") == 'true') && $(".goodVisionLink").length == 0);
#             var notPoorVision = (($.cookie("usePoorVisionOption") != 'true') && $(".poorVisionLink").length == 0);
#             if (notUsual || notPoorVision){
#                 location.reload();
#             }
#         });
#
#         $(window).ready(function() {
#             $('body').animate({opacity:'1'},300);
#         });
#     </script>
# <script src="/epz/static/js/jquery.dynatree.js" type="text/javascript"></script>
# <script src="/epz/static/js/jquery.ui.datepicker-ru.js" type="text/javascript"></script>
# <script src="/epz/static/js/moment.min.js" type="text/javascript"></script>
# <script src="/epz/static/js/moment-timezone.min.js" type="text/javascript"></script>
# <script src="/epz/static/js/validation/jquery.numeric.js" type="text/javascript"></script>
# <script src="/epz/static/js/action-switch.js" type="text/javascript"></script>
# <script src="/epz/static/js/browser.js" type="text/javascript"></script>
# <script src="/epz/static/js/app.js" type="text/javascript"></script>
# <script src="/epz/static/js/common/hints.js" type="text/javascript"></script>
# <script src="/epz/static/js/baseLayout.js" type="text/javascript"></script>
# <script src="/epz/static/js/script.js" type="text/javascript"></script>
# <script src="/epz/static/js/checkNotice.js" type="text/javascript"></script>
# <script src="/epz/static/js/common/config.js" type="text/javascript"></script>
# <script src="/epz/static/js/common/choose-headagency.js" type="text/javascript"></script>
# <script src="/epz/static/js/common/choose-okpd.js" type="text/javascript"></script>
# <script src="/epz/static/js/custom.js" type="text/javascript"></script>
# <script src="/epz/static/js/popupCommon.js" type="text/javascript"></script>
# <script src="/epz/static/js/common/choose-organization.js" type="text/javascript"></script>
# <script src="/epz/static/js/URI.js" type="text/javascript"></script>
# <script src="/epz/static/js/common/analytics.js" type="text/javascript"></script>
# <script src="/epz/static/js/jquery_msgBox.js" type="text/javascript"></script>
# <script src="/epz/static/js/keyboardControl.js" type="text/javascript"></script>
# <script src="/epz/static/js/customScrollbar.js" type="text/javascript"></script>
# <script src="/epz/static/js/keyboardNavigationRules.js" type="text/javascript"></script>
# <script type="text/javascript">if (!window.console) console = {
#         log: function () {
#         }
#     };</script>
# <script type="text/javascript">
#     epzCommonConfig.initCommonConfig({
#         contextPath: '/epz/order/extendedsearch',
#         smartSearchEnable: true,
#
#         urls: {
#             epzMainPublicUrl: '/epz/main/public/',
#             epzNsiUrl: '/epz/nsi/',
#             epzOrderUrl: '/epz/order/',
#             epzOrderPlanUrl: '/epz/orderplan/',
#             epzOrderClauseUrl: '/epz/orderclause/',
#             epzContractUrl: '/epz/contract/',
#             epzContractFz223Url: '/epz/contractfz223/',
#             epzContractReportingUrl: '/epz/contractreporting/',
#             epzCustomerReportsUrl: '/epz/customerreports/',
#             epzOrganizationUrl: '/epz/organization/',
#             epzDishonestSupplierUrl: '/epz/dishonestsupplier/',
#             epzComplaintUrl: '/epz/complaint/',
#             epzBankGuaranteeUrl: '/epz/bankguarantee/',
#             epzInspectionPlanUrl: '/epz/inspectionplan/',
#             epzUnscheduledInspectionUrl: '/epz/unscheduledinspection/',
#             epzControlResultUrl: '/epz/controlresult/',
#             epzDizkUrl: '/epz/dizk/',
#             epzEsUrl: '/analytics/hit/',
#             epzFarmUrl: '/epz/farm/'
#         }
#     });
# </script>
# </link></head>
# <body>
# <script type="text/javascript">
#     if ($.cookie('usePoorVisionOption') === 'true') {
#         var body = $('body');
#         var style = '', styleColor = '';
#         var color = $.cookie('colorSpectrumForPoorVision');
#         body.addClass('poorVision');
#         if (color) {
#             body.addClass(color + 'ColorSpectrum');
#             switch (color) {
#                 case 'white':
#                     style = '#ffffff';
#                     styleColor = '#000000';
#                     break;
#                 case 'black':
#                     style = '#000000';
#                     styleColor = '#ffffff'
#                     break;
#                 case 'blue':
#                     style = '#9DD1FF';
#                     styleColor = '#063462';
#                     break;
#                 case 'brown':
#                     style = '#442713';
#                     styleColor = '#a9e44d';
#                     break;
#                 case 'biege':
#                     style = '#F7F3D6';
#                     styleColor = '#49442e';
#                     break;
#                 default:
#                     break;
#             }
#             body.css({backgroundColor: style, color:styleColor});
#         }else{
#             body.addClass('whiteColorSpectrum');
#         }
#
#         var fontSize = $.cookie('fontSizeForPoorVision');
#         if (fontSize) {
#             body.addClass('fontSizeForPoorVision' + fontSize);
#         }else{
#             body.addClass('fontSizeForPoorVision100');
#         }
#     }
# </script>
# <style>
#     .header-logo {
#         top: -5px;
#         background: none;
#     }
# </style>
# <div id="critical_notice"></div>
# <header class="header header-top">
# <div class="container">
# <div class="row align-items-center">
# <div class="col-5" style="z-index: 1;">
# <span class="logo text-base-micro">Официальный сайт Единой информационной системы в сфере закупок</span>
# </div>
# <div class="col-1"></div>
# <div class="col-3">
# <a data-modalup="" href="/epz/nsi/kladr/chooseRegion.html">
# <div class="region d-flex align-items-center pr-0" data-target=".modal-region" data-toggle="modal-region">
# <span class="region-city w-space-nowrap">
# <span class="region-city__icon">
# <img src="/epz/static/img/icons/icon_region.svg" title="Информация о местоположении пользователя используется в поисковых запросах для динамической детализации результатов поиска."/>
# </span>
# <span class="region-city__text region-city__text_base text-base-micro">Мой регион: </span>
# </span>
# <span id="chooseRegion">
# <span class="region-city pl-1">
# <span class="region-city__text region-city__text_prime text-base-micro region_name" id="popUpUserRegion">
# </span>
# </span>
# <span class="region-city__icon pl-1">
# <img alt="" src="/epz/static/img/icons/icon_arrow_region.svg"/>
# </span>
# </span>
# </div>
# </a>
# </div>
# <div class="col-1">
# <div class="header-links-group offset-block">
# <a class="header-link header-link_top" href="#">
# <span class="header-link__icon poorVisionLink">
# <img alt="" class="glass-icon" src="/epz/static/img/icons/icon_eye.svg"/>
# </span>
# </a>
# </div>
# </div>
# <div class="col-2">
# <div class="account">
# <div class="account-block">
# <span class="icon">
# <img alt="" src="/epz/static/img/icons/icon_user.svg"/>
# </span>
# <span class="text padLeft4">Личный кабинет</span>
# <span class="button-open icon">
# <img alt="" src="/epz/static/img/icons/icon_arrow_lk.svg"/>
# </span>
# </div>
# <ul class="account-vars">
# <li class="account__var" data-toggle="modal-account44">
# <a class="account__link" data-modalup="" href="/epz/main/public/chooseAuth44.html" target="_blank">
# <span class="icon">
# <img alt="" src="/epz/static/img/icons/arrow.svg"/>
# </span>
z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M54.2795 30.9572V32.513H55.8446V30.9572H54.2795Z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M74.9626 30.9572V32.513H76.5222V30.9572H74.9626Z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M33.6021 30.9572V32.513H35.1671V30.9572H33.6021Z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M36.1899 36.1157V37.6716H37.7495V36.1157H36.1899Z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M77.5454 36.1157V37.6716H79.1049V36.1157H77.5454Z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M56.8677 36.1157V37.6716H58.4272V36.1157H56.8677Z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M15.5071 36.1157V37.6716H17.0721V36.1157H15.5071Z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M46.5261 36.1157V37.6716H48.0912V36.1157H46.5261Z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M87.887 36.1157V37.6716H89.4465V36.1157H87.887Z" fill="#0065DD" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M67.2039 36.1157V37.6716H68.7689V36.1157H67.2039Z" fill="#0065DD" fill-rule="evenodd"></path>
# ...
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="block fz44_tag search_tag">
# <div class="row PurchaseObjectTagRow">
# <!-- Признак но основе которого определяется что тэг должен показываться по умолчанию -->
# </div>
# </div>
# <div class="block fz44_tag search_tag">
# <div class="row TagRow">
# <!-- Признак но основе которого определяется что тэг должен показываться по умолчанию -->
# </div>
# </div>
# <div class="block fz44_tag search_tag">
# <div class="row MedicinesGroupTagRow">
# <!-- Признак но основе которого определяется что тэг должен показываться по умолчанию -->
# </div>
# </div>
# <div class="block fz94_tag search_tag">
# <div class="row orderPlacement94TagRow">
# <!-- Признак но основе которого определяется что тэг должен показываться по умолчанию -->
# </div>
# </div>
# <div class="block fz94_tag search_tag">
# <div class="row ContractGroupTagRow">
# <!-- Признак но основе которого определяется что тэг должен показываться по умолчанию -->
# </div>
# </div>
# <div class="block fz94_tag search_tag">
# <div class="row OrderComplaintsGroupTagRow">
# <!-- Признак но основе которого определяется что тэг должен показываться по умолчанию -->
# </div>
# </div>
# <div class="block fz94_tag search_tag">
# <div class="row InspectionGroupTagRow">
# <!-- Признак но основе которого определяется что тэг должен показываться по умолчанию -->
# </div>
# </div>
# <div class="block fz44_tag fz94_tag fz223_tag ppRf615_tag search_tag">
# <div class="row TagRow">
# <!-- Признак но основе которого определяется что тэг должен показываться по умолчанию -->
# </div>
# </div>
# <div class="block border-with-botandtop">
# <div class="row">
# <div class="input-group col-12 mb-1 mt-2">
# <a class="btn-icon__text display-flex justify-content-between" href="#" onclick="goExtendedSearch('/epz/order/extendedsearch/search.html')">
# <span class="btn-icon__icon">Все параметры</span>
# <span id="all-search-options-bottom"><img alt="" src="/epz/static/img/icons/arrow_blue.svg"/></span>
# </a>
# </div>
# </div>
# </div>
# <div class="block none-border padTop40">
# <div class="row">
# <div class="col-12">
# <div class="input-group">
# <button class="btn btn-primary" onclick="submitQuickSearchForm(); return false;">
# <span class="btn-text">Применить</span>
# </button>
# </div>
# </div>
# <div class="col-12" style="margin-top: 16px;">
# <div class="input-group">
# <div class="btn btn-default" onclick="SAVED_SETTINGS().saveAndSubmit(submitQuickSearchForm)">
# <span class="btn-text" id="saveSettingsBtnLabel">Сохранить параметры</span>
# </div>
# </div>
# </div>
# </div>
# <div class="btn-clear clear-form d-flex align-items-center justify-content-end mr-t" id="clearAll">
# <span class="btn-icon">
# <img alt="" src="/epz/static/img/icons/icon_cross_btn.svg"/>
# </span>
# <span class="btn-text clearAll">Очистить форму</span>
# </div>
# </div>
# </div>
# <script>
#     $(document).ready(function () {
#         $("#clearAll").click(function () {
#             clearAllSearchForm();
#         });
#
#         if (SAVED_SETTINGS().isSettingSelected()) {
#             $("#saveSettingsBtnLabel").text("Изменить параметры");
#         }
#     });
# </script>
# </div>
# </div>
# </div>
# </section>
# </form>
# <footer class="footer">
# <div class="wrapperFooter">
# <div class="container">
# <div class="poll-banner">
# <div class="row align-items-center">
# <div class="col-9">
# <div class="figure-footer d-flex align-items-center">
# <div class="figure-footer__icon">
# <img alt="" class="icon" src="/epz/static/img/icons/ico_sub.svg"/>
# </div>
# <div class="figure-footer__text">
# <h4 class="heading-h4 poll-title">Поделитесь мнением о качестве работы единой
#                                                 информационной системы</h4>
# </div>
# </div>
# </div>
# <div class="col-3 text-right">
# <a class="btn btn-default poll-button" href="/epz/main/public/quiz/list.html">
# <span class="separator"></span>
# <span class="btn-text">Перейти к опросу</span>
# </a>
# </div>
# </div>
# <figure class="poll__logo">
# <img alt="" src="/epz/static/img/icons/icon-footer-eagle.svg"/>
# </figure>
# </div>
# </div>
# <div class="container">
# <div class="partners-wrap">
# <div class="partners partners-slider">
# <figure class="partner">
# <p class="partner-logo-wrap">
# <a href="http://www.sberbank-ast.ru/" target="_blank"><img alt="" class="partner__logo" src="/epz/static/img/partners/sberbank_new.svg"/></a>
# </p>
# <figcaption class="partner__desc"> Система торгов <br/> Сбербанк-АСТ
#                                 </figcaption>
# <a class="partner__link" href="http://www.sberbank-ast.ru/" target="_blank">sberbank-ast.ru</a>
# </figure>
# <figure class="partner">
# <p class="partner-logo-wrap">
# <a href="http://www.roseltorg.ru/" target="_blank"><img alt="" class="partner__logo" src="/epz/static/img/partners/rostorg_new.svg"/></a>
# </p>
# <figcaption class="partner__desc"> Единая электронная торговая <br/> площадка
#                                 </figcaption>
# <a class="partner__link" href="http://www.roseltorg.ru/" target="_blank">roseltorg.ru</a>
# </figure>
# <figure class="partner">
# <p class="partner-logo-wrap">
# <a href="http://etp.zakazrf.ru/" target="_blank"><img alt="" class="partner__logo" src="/epz/static/img/partners/etp.svg"/></a>
# </p>
# <figcaption class="partner__desc"> Общероссийская система <br/> электронной торговли
#                                 </figcaption>
# <a class="partner__link" href="http://etp.zakazrf.ru/" target="_blank">etp.zakazrf.ru</a>
# </figure>
# <figure class="partner">
# <p class="partner-logo-wrap">
# <a href="http://www.rts-tender.ru/" target="_blank"><img alt="" class="partner__logo" src="/epz/static/img/partners/rts.svg"/></a>
# </p>
# <figcaption class="partner__desc"> Электронная площадка <br/> России
#                                 </figcaption>
# <a class="partner__link" href="http://www.rts-tender.ru/" target="_blank">rts-tender.ru</a>
# </figure>
# <figure class="partner">
# <p class="partner-logo-wrap">
# <a href="http://etp-ets.ru/" target="_blank"><img alt="" class="partner__logo" src="/epz/static/img/partners/ets.svg"/></a>
# </p>
# <figcaption class="partner__desc"> Электронная торговая <br/> площадка «Фабрикант»
#                                 </figcaption>
# <a class="partner__link" href="http://etp-ets.ru/" target="_blank">etp-ets.ru</a>
# </figure>
# <figure class="partner">
# <p class="partner-logo-wrap">
# <a href="https://gz.lot-online.ru" target="_blank"><img alt="" class="partner__logo" src="/epz/static/img/partners/newGZ.svg"/></a>
# </p>
# <figcaption class="partner__desc"> Всероссийская <br/> универсальная площадка
#                                 </figcaption>
# <a class="partner__link" href="https://gz.lot-online.ru" target="_blank">gz.lot-online.ru</a>
# </figure>
# <figure class="partner">
# <p class="partner-logo-wrap">
# <a href="https://www.tektorg.ru/" target="_blank"><img alt="" class="partner__logo" src="/epz/static/img/partners/tektorg_new.svg"/></a>
# </p>
# <figcaption class="partner__desc"> Федеральная электронная<br>площадка ТЭК-Торг
#
#                                 </br></figcaption>
# <a class="partner__link" href="https://www.tektorg.ru/" target="_blank">tektorg.ru</a>
# </figure>
# <figure class="partner">
# <p class="partner-logo-wrap">
# <a href="https://etpgpb.ru/" target="_blank"><img alt="" class="partner__logo" src="/epz/static/img/partners/etpgpb.svg"/></a>
# </p>
# <figcaption class="partner__desc"> Электронная торговая<br>площадка ГПБ
#                                 </br></figcaption>
# <a class="partner__link" href="https://etpgpb.ru/" target="_blank">etpgpb.ru</a>
# </figure>
# <figure class="partner">
# <p class="partner-logo-wrap">
# <a href="http://www.astgoz.ru/" target="_blank"><img alt="" class="partner__logo" src="/epz/static/img/partners/astgoz.svg"/></a>
# </p>
# <figcaption class="partner__desc"> Автоматизированная система торгов государственного
#                                     оборонного
#                                     заказа <br/></figcaption>
# <a class="partner__link" href="http://www.astgoz.ru/" target="_blank">astgoz.ru</a>
# </figure>
# </div>
# <span class="partners-slider__btn partners-slider__btn_prev">
# <img alt="" src="/epz/static/img/icons/arrow_blue.svg"/>
# </span>
#                         <span class="partners-slider__btn partners-slider__btn_next">
# <img alt="" src="/epz/static/img/icons/arrow_blue.svg"/>
# </span>
#                     </div>
# </div>
# <section class="footer-nav">
# <div class="container">
# <div class="row">
# <div class="col-md-12 col-lg-12">
# <ul class="footer-nav-list">
# <li class="footer-nav__item">
# <a class="footer-nav__link" href="/epz/main/public/news/news-search.html">Новости</a>
# </li>
# <li class="footer-nav__item">
# <a class="footer-nav__link" href="/epz/main/public/siteMap.html?section=suppliers">Поставщикам</a>
# </li>
# <li class="footer-nav__item">
# <a class="footer-nav__link" href="/epz/main/public/siteMap.html?section=customers">Заказчикам</a>
# </li>
# <li class="footer-nav__item">
# <a class="footer-nav__link" href="/epz/main/public/siteMap.html?section=control-bodies">Органам контроля</a>
# </li>
# <li class="footer-nav__item">
# <a class="footer-nav__link" href="/epz/main/public/quiz/list.html">Опросы</a>
# </li>
# <li class="footer-nav__item">
# <a class="footer-nav__link" href="/epz/main/public/home.html#statAnchor">Статистика</a>
# </li>
# <li class="footer-nav__item">
# <a class="footer-nav__link" href="/epz/main/public/siteMap.html">Карта сайта</a>
# </li>
# <li class="footer-nav__item">
# <a class="footer-nav__link" href="https://zakupki.gov.ru/rpt/cat02/zakupki-traffic.xlsx">Отчет о посещаемости</a>
# </li>
# <li class="footer-nav__item">
# <a class="footer-nav__link" href="/epz/main/public/qa/view.html">Часто задаваемые вопросы</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </section>
# <section class="footer-links">
# <div class="container">
# <div class="row">
# <div class="col-4 col-sm-4 col-md-4 col-lg-4">
# <figure class="logo">
# <img alt="" src="/epz/static/img/header/emblem.svg"/>
# <figcaption class="logo__name filterParametrs"> Единая информационная система<br/> в сфере закупок</figcaption>
# </figure>
# <div class="copyright">
# <small class="copyright__text">© Федеральное казначейство, 2022</small>
# <small class="copyright__text"> Версия hotfix/12.2.10 rev3d8066da от 15.09.2022</small>
# </div>
# </div>
# <div class="col-4 col-sm-4 col-md-4 col-lg-4">
# <nav class="usefull-links">
# <span class="list-title">Официальные ресурсы</span>
# <ul class="list">
# <li class="list-item">
# <a class="list-item__link" href="http://www.kremlin.ru" target="_blank">Президент Российской Федерации</a>
# </li>
# <li class="list-item">
# <a class="list-item__link" href="http://www.government.ru" target="_blank">Правительство Российской Федерации</a>
# </li>
# <li class="list-item">
# <a class="list-item__link" href="http://www.economy.gov.ru" target="_blank">Министерство экономического развития Российской Федерации</a>
# </li>
# <li class="list-item">
# <a class="list-item__link" href="https://minfin.gov.ru" target="_blank">Министерство финансов Российской Федерации</a>
# </li>
# <li class="list-item">
# <a class="list-item__link" href="http://www.fas.gov.ru" target="_blank">Федеральная антимонопольная служба</a>
# </li>
# <li class="list-item">
# <a class="list-item__link" href="http://roskazna.ru" target="_blank">Федеральное казначейство</a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="col-4 col-sm-4 col-md-4 col-lg-4">
# <nav class="usefull-links">
# <span class="list-title">Техническая информация</span>
# <ul class="list">
# <li class="list-item">
# <a class="list-item__link" href="/epz/main/public/user-feedback.html">Техническая поддержка</a>
# </li>
# <li class="list-item">
# <a class="list-item__link" data-modalup="" href="/epz/main/public/userFeedback/openFeedbackForm.html">Ваши идеи по улучшению сайта</a>
# </li>
# </ul>
# </nav>
# <figure class="btn-on-top">
# <a class="btn-on-top__link">
# <img alt="" class="btn-on-top__image" src="/epz/static/img/icons/arrow-on-top.svg"/>
# </a>
# </figure>
# </div>
# </div>
# </div>
# </section>
# <div class="clear"></div>
# </div>
# </footer>
# <script src="/epz/static/js/openstreetmap.js"></script>
# <script src="/epz/static/js/openStreetMapCommonFunctions.js"></script>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#     (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#         m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#     (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#     ym(36706425, "init", {
#         clickmap:true,
#         trackLinks:true,
#         accurateTrackBounce:true,
#         webvisor:true
#     });
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/36706425" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <script type="text/javascript">if (window.epzAnalytics) window.epzAnalytics.track();
# $(document).ready(function () {
#     checkNotice();
#     let name = undefined;
#
#     if (contextPath.match("ktru")) {
#         $('.poorVision #morphology').parent().addClass('ktru-search-checkbox');
#         $('.poorVision #strictEqual').parent().addClass('ktru-search-checkbox');
#         var isPosition = ''.length > 0;
#         var isRubricator = ''.length > 0;
#         var ktruRubricatorSelectedSection;
#         if (isPosition) {
#             ktruRubricatorSelectedSection = '<div class="col-12 mb-3" id="ktruRubricatorSelectedSection"><a class="url41484e cursorPointer" onclick="goToSearchUrl(false,  &#39;&#39;, true)"><img class="mr-3" src="/epz/static/img/icons/arrow-prime.svg" style="transform: rotate(180deg)" alt="">Назад к категориям</a> &#9656; </div>';
#             name = getKtruName("");
#         }  else {
#             if (isRubricator) {
#                 ktruRubricatorSelectedSection = '<div class="col-12 mb-3" id="ktruRubricatorSelectedSection"><a class="url41484e cursorPointer" href="/epz/order/extendedsearch/start/startPage.html"><img class="mr-3" src="/epz/static/img/icons/arrow-prime.svg" style="transform: rotate(180deg)" alt="">Назад к рубрикам</a> &#9656; </div>';
#             }else if(!isRubricator && !isPosition){
#                 ktruRubricatorSelectedSection = '<div class="col-12 mb-3" id="ktruRubricatorSelectedSection"><a class="url41484e cursorPointer" href="/epz/order/extendedsearch/start/startPage.html"><img class="mr-3" src="/epz/static/img/icons/arrow-prime.svg" style="transform: rotate(180deg)" alt="">Назад к рубрикам</a></div>';
#             }
#         }
#         if (isPosition || isRubricator) {
#             var ktruRubricatorSelectedSectionSelector;
#             if ($(".search-quick .search-results").length > 0) {
#                 ktruRubricatorSelectedSectionSelector = ".search-quick .search-results";
#             } else {
#                 ktruRubricatorSelectedSectionSelector = ".paramegnimtrs h3";
#             }
#             $(ktruRubricatorSelectedSectionSelector).before(ktruRubricatorSelectedSection);
#         }else{
#             if(!isRubricator && !isPosition){
#                 $(".search-quick .search-results").before(ktruRubricatorSelectedSection);
#             }
#         }
#     }
#     if (contextPath.match("orderplan") && "".length > 0) {
#         $(".search-quick .search-results").before('<div class="col-12 mb-3" id="ktruRubricatorSelectedSection">' +
#             '<a class="url41484e cursorPointer" onclick="goToSearchUrl(false, &#39;&#39;)"><img class="mr-3" src="/epz/static/img/icons/arrow-prime.svg" style="transform: rotate(180deg)" alt="">Назад к результатам поиска</a> &#9656; № </div>');
#         name = '';
#     }
#     if (contextPath.match("purchaseplan") && "".length > 0) {
#         $(".search-quick .search-results").before('<div class="col-12 mb-3" id="ktruRubricatorSelectedSection">' +
#             '<a class="url41484e cursorPointer" onclick="goToSearchUrl(false, &#39;&#39;)"><img class="mr-3" src="/epz/static/img/icons/arrow-prime.svg" style="transform: rotate(180deg)" alt="">Назад к результатам поиска</a> &#9656; № </div>');
#         name = '';
#     }
#
#     if(name && name != null) {
#         if(sessionStorage.getItem(name) == null) {
#             sessionStorage.setItem(name, document.referrer);
#         }
#     }
# });
# </script>
# <div id="custom-tooltip"></div>
# </body>
# </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.find_all('div', class_='registry-entry__header-mid__number')
# Out:
# [<div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14424358" target="_blank">
#                                          № 32211698748
#                                      </a>
#  </div>,
#  <div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14423250" target="_blank">
#                                          № 32211698747
#                                      </a>
#  </div>,
#  <div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14398602" target="_blank">
#                                          № 32211677683
#                                      </a>
#  </div>,
#  <div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14424352" target="_blank">
#                                          № 32211698744
#                                      </a>
#  </div>,
#  <div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14424350" target="_blank">
#                                          № 32211698743
#                                      </a>
#  </div>,
#  <div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14424351" target="_blank">
#                                          № 32211698742
#                                      </a>
#  </div>,
#  <div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14396665" target="_blank">
#                                          № 32211676172
#                                      </a>
#  </div>,
#  <div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14405316" target="_blank">
#                                          № 32211683270
#                                      </a>
#  </div>,
#  <div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14391878" target="_blank">
#                                          № 32211672326
#                                      </a>
#  </div>,
#  <div class="registry-entry__header-mid__number">
#  <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14399201" target="_blank">
#                                          № 32211678320
#                                      </a>
#  </div>]

# %%
soup.find_all('div', class_='registry-entry__header-mid__number')[0]
# Out:
# <div class="registry-entry__header-mid__number">
# <a href="/epz/order/notice/notice223/common-info.html?noticeInfoId=14424358" target="_blank">
#                                         № 32211698748
#                                     </a>
# </div>

# %%
soup.find_all('div', class_='registry-entry__header-mid__number')[0].text
# Out:
# '\n\n                                        № 32211698748\n                                    \n'

# %%
# %%time

numbers_list = [] 
placements_dates_list = []
update_dates_list = []
finish_dates_list = []
objects_list = []
prices_list = []

procurements_status_dict = {}

for i, url in enumerate(urls_list):
    print(url, end=" ")
    # TODO: добавить try-except и цикл, чтобы несколько раз пытаться подключиться
    page = requests.get(url) # отправляем запрос
    print(page.status_code)
    
    procurements_status_dict[url] = page.status_code
    
    if page.status_code == 200: # если ссылка рабочая, код = 200
        soup = BeautifulSoup(page.text, 'html.parser')
    else:
        print("Не удалось подключиться", page.status_code)
        continue
        
    # Ищем номера закупок
    numbers = soup.find_all('div', class_='registry-entry__header-mid__number') # ищем номер заявки
    if numbers:
        numbers_list.append([number.text for number in numbers])
    else:
        numbers_list.append(np.nan)
        
    
    # TODO: Добавить проверки, что у закупки есть все три даты 
    # TODO: Например, пропускать те закупки, где нет всех трех дат, проверку делать отдельно до сохранения в списки
    dates = soup.find_all('div', class_='data-block__value') # ищем дату размещения
    if dates:
        placements_dates_list.append([dates[i].text for i in range(0, len(dates), 3)])
        update_dates_list.append([dates[i].text for i in range(1, len(dates), 3)])
        finish_dates_list.append([dates[i].text for i in range(2, len(dates), 3)])
    else:
        placements_dates_list.append(np.nan)
        update_dates_list.append(np.nan)
        finish_dates_list.append(np.nan)
        
    
    objects = soup.find_all('div', class_='registry-entry__body-value') # ищем объекты закупок
    if objects:
        objects_list.append([object_.text for object_ in objects])
    else:
        objects_list.append(np.nan)
    
    prices = soup.find_all('div', class_='price-block__value') # ищем цены закупок
    if prices:
        prices_list.append([price.text for price in prices])
    else:
        prices_list.append(np.nan)

    # TODO: менять паузу
    time.sleep(2.0) # пауза для обхода блокировки
# Out:
# https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=2&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes= 200
# https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=3&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes= 200
# https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=4&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes= 404
# Не удалось подключиться 404
# Wall time: 5.8 s

# %%
import random

random.random() * 2
# Out:
# 1.01237623932578

# %%
procurements_status_dict
# Out:
# {'https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=2&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes=': 200,
#  'https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=3&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes=': 200,
#  'https://zakupki.gov.ru/epz/order/extendedsearch/results.html?searchString=&morphology=on&search-filter=Дате+обновления&pageNumber=4&sortDirection=false&recordsPerPage=_10&showLotsInfoHidden=false&savedSearchSettingsIdHidden=&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&placingWayList=&selectedLaws=&priceFromGeneral=&priceFromGWS=&priceFromUnitGWS=&priceToGeneral=&priceToGWS=&priceToUnitGWS=&currencyIdGeneral=-1&publishDateFrom=&publishDateTo=&applSubmissionCloseDateFrom=&applSubmissionCloseDateTo=&customerIdOrg=&customerFz94id=&customerTitle=&okpd2Ids=&okpd2IdsCodes=': 404}

# %%
prices_list
# Out:
# [['116\xa0852,00 ₽\n                            ',
#   '5\xa0312\xa0719,74 ₽\n                            ',
#   '358\xa0458,48 ₽\n                            ',
#   '209\xa0165,00 ₽\n                            ',
#   '4\xa0910\xa0306,75 ₽\n                            ',
#   '636\xa0085,29 ₽\n                            ',
#   '82\xa0883,32 ₽\n                            ',
#   '85\xa0438,00 ₽\n                            ',
#   '186\xa0180,00 ₽\n                            ',
#   '157\xa0875,00 ₽\n                            '],
#  ['112\xa0000,00 ₽\n                            ',
#   '1\xa0695\xa0400,00 ₽\n                            ',
#   '33\xa0703\xa0486,00 ₽\n                            ',
#   '419\xa0520,00 ₽\n                            ',
#   '204\xa0264,00 ₽\n                            ',
#   '666\xa0407,00 ₽\n                            ',
#   '162\xa0740,00 ₽\n                            ',
#   '119\xa0292,00 ₽\n                            ',
#   '329\xa0547,50 ₽\n                            ',
#   '307\xa0132,00 ₽\n                            ']]

# %%
prices_list[0][0]
# Out:
# '116\xa0852,00 ₽\n                            '

# %%
type(prices_list[0][0])
# Out:
# str

# %%
price_ = re.sub("[^0-9,₽]", "", prices_list[0][0])

# %%
type(price_)
# Out:
# str

# %%
price_
# Out:
# '116852,00₽'

# %%
float(price_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15660/463574243.py in <module>
# ----> 1 float(price_)
#
# ValueError: could not convert string to float: '116852,00₽'

# %%
price_ = re.sub("[^0-9,]", "", prices_list[0][0])

# %%
price_
# Out:
# '116852,00'

# %%
type(price_)
# Out:
# str

# %%
price_.replace(',', '.')
# Out:
# '116852.00'

# %%
float(price_.replace(',', '.'))
# Out:
# 116852.0

# %%
price_float = float(price_.replace(',', '.'))

# %%
type(price_float)
# Out:
# float

# %%
price_float
# Out:
# 116852.0

# %%
currency = prices_list[0][0].split()[-1]

# %%
currency
# Out:
# '₽'

# %%
prices_list[0]
# Out:
# ['116\xa0852,00 ₽\n                            ',
#  '5\xa0312\xa0719,74 ₽\n                            ',
#  '358\xa0458,48 ₽\n                            ',
#  '209\xa0165,00 ₽\n                            ',
#  '4\xa0910\xa0306,75 ₽\n                            ',
#  '636\xa0085,29 ₽\n                            ',
#  '82\xa0883,32 ₽\n                            ',
#  '85\xa0438,00 ₽\n                            ',
#  '186\xa0180,00 ₽\n                            ',
#  '157\xa0875,00 ₽\n                            ']

# %%
len(numbers_list[0])
# Out:
# 10

# %%
len(objects_list[0])
# Out:
# 10

# %% [markdown]
# ---

# %%
numbers_list[0][0]
# Out:
# '\n\n                                        № 32211698748\n                                    \n'

# %%
placements_dates_list[0][0]
# Out:
# '17.09.2022'

# %%
update_dates_list[0][0]
# Out:
# '17.09.2022'

# %%
objects_list[0][0]
# Out:
# 'Поставка филе минтая'

# %%
prices_list[0][0]
# Out:
# '116\xa0852,00 ₽\n                            '

# %%
procurements = []

# Проходим по всем страницам
for numbers, placements_dates, update_dates, finish_dates, objects_, prices in zip(numbers_list, 
                                                                                    placements_dates_list,
                                                                                    update_dates_list, 
                                                                                    finish_dates_list, 
                                                                                    objects_list, 
                                                                                    prices_list):
    # Проходим по всем закупкам
    for number, placements_date, update_date, finish_date, object_, price in zip(numbers, 
                                                                                 placements_dates, 
                                                                                 update_dates, 
                                                                                 finish_dates, 
                                                                                 objects_, 
                                                                                 prices ):
        # TODO: сохранять валюту (единица измерения)                                                                       
        procurements.append({
            "Номер закупки": re.sub("[^0-9]", "", number),
            "Дата размещения": placements_date,
            "Дата обновления": update_date,
            "Дата окончания": finish_date,
            "Объект закупки": object_,
            "Начальная цена": re.sub("[^0-9,]", "", price)
        })

# %%
procurements
# Out:
# [{'Номер закупки': '32211698748',
#   'Дата размещения': '17.09.2022',
#   'Дата обновления': '17.09.2022',
#   'Дата окончания': '26.09.2022',
#   'Объект закупки': 'Поставка филе минтая',
#   'Начальная цена': '116852,00'},
#  {'Номер закупки': '32211698747',
#   'Дата размещения': '17.09.2022',
#   'Дата обновления': '17.09.2022',
#   'Дата окончания': '24.09.2022',
#   'Объект закупки': 'Электронный аукцион на право заключения договора на оказание услуг по организации питания учащихся в 2022-2023гг',
#   'Начальная цена': '5312719,74'},
#  {'Номер закупки': '32211677683',
#   'Дата размещения': '08.09.2022',
#   'Дата обновления': '08.09.2022',
#   'Дата окончания': '16.09.2022',
#   'Объект закупки': 'Поставка продуктов питания-соки (фруктовые, овощные) и вода для детского питания',
#   'Начальная цена': '358458,48'},
#  {'Номер закупки': '32211698744',
#   'Дата размещения': '17.09.2022',
#   'Дата обновления': '17.09.2022',
#   'Дата окончания': '26.09.2022',
#   'Объект закупки': 'Поставка пеленок и бахил',
#   'Начальная цена': '209165,00'},
#  {'Номер закупки': '32211698743',
#   'Дата размещения': '17.09.2022',
#   'Дата обновления': '17.09.2022',
#   'Дата окончания': '27.09.2022',
#   'Объект закупки': 'Поставка  стоматологических расходных материалов на 2022год( из средств ОМС )\n',
#   'Начальная цена': '4910306,75'},
#  {'Номер закупки': '32211698742',
#   'Дата размещения': '17.09.2022',
#   'Дата обновления': '17.09.2022',
#   'Дата окончания': '27.09.2022',
#   'Объект закупки': 'Поставка  лекарственных средств на 2022год( из средств ОМС и из средств  от оказания платных услуг ( собственных средств)\n',
#   'Начальная цена': '636085,29'},
#  {'Номер закупки': '32211676172',
#   'Дата размещения': '08.09.2022',
#   'Дата обновления': '08.09.2022',
#   'Дата окончания': '17.09.2022',
#   'Объект закупки': 'поставка лабораторной мельницы',
#   'Начальная цена': '82883,32'},
#  {'Номер закупки': '32211683270',
#   'Дата размещения': '12.09.2022',
#   'Дата обновления': '12.09.2022',
#   'Дата окончания': '17.09.2022',
#   'Объект закупки': 'Канцелярские и хозяйственные товары',
#   'Начальная цена': '85438,00'},
#  {'Номер закупки': '32211672326',
#   'Дата размещения': '06.09.2022',
#   'Дата обновления': '06.09.2022',
#   'Дата окончания': '14.09.2022',
#   'Объект закупки': 'Приобретение газа углеводородного сжиженного для заправки автотранспорта марки ПБТ, с применением пластиковых карт',
#   'Начальная цена': '186180,00'},
#  {'Номер закупки': '32211678320',
#   'Дата размещения': '08.09.2022',
#   'Дата обновления': '08.09.2022',
#   'Дата окончания': '16.09.2022',
#   'Объект закупки': 'Поставка продуктов питания (хлеб и хлебобулочные изделия)',
#   'Начальная цена': '157875,00'},
#  {'Номер закупки': '32211678318',
#   'Дата размещения': '08.09.2022',
#   'Дата обновления': '08.09.2022',
#   'Дата окончания': '16.09.2022',
#   'Объект закупки': 'Поставка продуктов питания (яйцо куриное)',
#   'Начальная цена': '112000,00'},
#  {'Номер закупки': '32211698740',
#   'Дата размещения': '17.09.2022',
#   'Дата обновления': '17.09.2022',
#   'Дата окончания': '17.09.2022',
#   'Объект закупки': 'Поставка пельменей, вареников с творогом до 31.12.2022 ',
#   'Начальная цена': '1695400,00'},
#  {'Номер закупки': '32211698756',
#   'Дата размещения': '17.09.2022',
#   'Дата обновления': '14.09.2022',
#   'Дата окончания': '14.09.2022',
#   'Объект закупки': 'Закупка мазута ',
#   'Начальная цена': '33703486,00'},
#  {'Номер закупки': '32211692342',
#   'Дата размещения': '06.09.2022',
#   'Дата обновления': '06.09.2022',
#   'Дата окончания': '14.09.2022',
#   'Объект закупки': 'Оказание услуг сервисного технического обслуживания компьютерной техники, оборудования для нужд АО "766 УПТК".',
#   'Начальная цена': '419520,00'},
#  {'Номер закупки': '32211672325',
#   'Дата размещения': '24.08.2022',
#   'Дата обновления': '24.08.2022',
#   'Дата окончания': '14.09.2022',
#   'Объект закупки': 'Поставка горюче-смазочных материалов через сеть АЗС с применением электронных «Смарт-карт» (бензин)',
#   'Начальная цена': '204264,00'},
#  {'Номер закупки': '32211642702',
#   'Дата размещения': '14.09.2022',
#   'Дата обновления': '14.09.2022',
#   'Дата окончания': '14.09.2022',
#   'Объект закупки': 'Поставка компаунда для нужд АО «766 УПТК».',
#   'Начальная цена': '666407,00'},
#  {'Номер закупки': '32211692364',
#   'Дата размещения': '09.09.2022',
#   'Дата обновления': '09.09.2022',
#   'Дата окончания': '17.09.2022',
#   'Объект закупки': 'Оказание услуг по перевозке груза для нужд АО «766 УПТК»',
#   'Начальная цена': '162740,00'}]

# %%
df = pd.DataFrame(procurements)
df.head()
# Out:
#   Номер закупки Дата размещения Дата обновления Дата окончания  \
# 0   32211698748      17.09.2022      17.09.2022     26.09.2022
# 1   32211698747      17.09.2022      17.09.2022     24.09.2022
# 2   32211677683      08.09.2022      08.09.2022     16.09.2022
# 3   32211698744      17.09.2022      17.09.2022     26.09.2022
# 4   32211698743      17.09.2022      17.09.2022     27.09.2022
#
#                                       Объект закупки Начальная цена
# 0                               Поставка филе минтая      116852,00
# 1  Электронный аукцион на право заключения догово...     5312719,74
# 2  Поставка продуктов питания-соки (фруктовые, ов...      358458,48
# 3                           Поставка пеленок и бахил      209165,00
# 4  Поставка  стоматологических расходных материал...     4910306,75

# %%
df.to_csv("gov2.csv", encoding="utf-8")
